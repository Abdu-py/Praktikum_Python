# %% [markdown]
# # 🧾 LAPORAN PRAKTIKUM 4
#
# **Nama:** M. Abdu Mukhlisin Mawardi
# **NIM:** 2402038
# **Kelas:** 3A
# **Mata Kuliah:** Praktikum Algoritma dan Pemrograman
# **Dosen Pengampu:** Heny Indriani, S.T., M.M., M.Kom.

# %% [markdown]
# ## 1. Pendahuluan
# Pada praktikum ini mahasiswa diminta untuk membuat beberapa program sederhana menggunakan bahasa pemrograman Python. Program yang dibuat meliputi operasi dasar seperti perhitungan matriks, perhitungan total pembelian, identifikasi bilangan ganjil/genap, serta tampilan pola angka. Tujuannya adalah untuk melatih kemampuan logika, pemahaman struktur perulangan, kondisi, dan manipulasi data.

# %% [markdown]
# ## 2. Tujuan dan Manfaat
# **Tujuan:**
# 1. Mahasiswa dapat memahami konsep perulangan (looping) dan percabangan (if-else).
# 2. Mahasiswa mampu membuat program sederhana untuk menyelesaikan permasalahan logika.
# 3. Mahasiswa dapat mengimplementasikan algoritma matematika ke dalam bentuk kode program.
#
# **Manfaat:**
# 1. Melatih kemampuan berpikir logis dan sistematis.
# 2. Meningkatkan kemampuan pemecahan masalah dengan pemrograman.
# 3. Menjadi dasar untuk mempelajari struktur data dan algoritma yang lebih kompleks.

# %% [markdown]
# ## 3. Program

# %%
# Program 1: Penjumlahan Dua Matriks
A = [[1, 2], [3, 4]]
B = [[5, 6], [7, 8]]

hasil = [[0, 0], [0, 0]]

for i in range(len(A)):
    for j in range(len(A[0])):
        hasil[i][j] = A[i][j] + B[i][j]

print("Hasil Penjumlahan Matriks:")
for r in hasil:
    print(r)

# %%
# Program 2: Total Pembelian N Barang
total = 0
N = int(input("Masukkan jumlah barang: "))

for i in range(N):
    harga = float(input(f"Masukkan harga barang ke-{i+1}: "))
    jumlah = int(input(f"Masukkan jumlah barang ke-{i+1}: "))
    total += harga * jumlah

print("Total pembelian =", total)

# %%
# Program 3: Hitung Bilangan Ganjil dan Genap
N = int(input("Masukkan banyak bilangan: "))
ganjil = genap = 0

for i in range(N):
    bil = int(input(f"Masukkan bilangan ke-{i+1}: "))
    if bil % 2 == 0:
        genap += 1
    else:
        ganjil += 1

print("Jumlah bilangan genap:", genap)
print("Jumlah bilangan ganjil:", ganjil)

# %%
# Program 4: Bilangan Kelipatan 3
a = int(input("Masukkan batas awal: "))
b = int(input("Masukkan batas akhir: "))

print("Bilangan kelipatan 3 diantara", a, "dan", b, ":")
for i in range(a, b + 1):
    if i % 3 == 0:
        print(i, end=" ")

# %%
# Program 5: Pola Angka Bertingkat
n = int(input("Masukkan bilangan: "))

for i in range(1, n + 1):
    for j in range(1, i + 1):
        print(j, end="")
    print()

# %%
# Program 6: Menghitung Nilai Akhir Mahasiswa
n = int(input("Masukkan jumlah mahasiswa: "))

for i in range(1, n + 1):
    nama = input(f"Nama mahasiswa ke-{i}: ")
    tugas = float(input("Nilai Tugas: "))
    kuis = float(input("Nilai Kuis: "))
    uts = float(input("Nilai UTS: "))
    uas = float(input("Nilai UAS: "))

    nilai_akhir = (tugas * 0.2) + (kuis * 0.2) + (uts * 0.3) + (uas * 0.3)
    print(f"{i}. {nama} - Nilai Akhir: {nilai_akhir:.2f}")

# %% [markdown]
# ## 4. Analisis Program
# Setiap program di atas mengimplementasikan logika dasar dalam pemrograman:
# - **Perulangan (for loop)** digunakan untuk iterasi data seperti pengisian nilai matriks atau daftar barang.
# - **Kondisi (if-else)** digunakan untuk memeriksa genap/ganjil dan menentukan kelipatan.
# - **Input/output** digunakan untuk interaksi dengan pengguna.
# - Program 1–6 menunjukkan penerapan konsep dasar seperti aritmatika, struktur data list, dan tampilan pola.
#
# Dengan mengerjakan latihan ini, mahasiswa memahami hubungan antara teori algoritma dan implementasi nyata dalam bahasa Python.

# %% [markdown]
# ## 5. Referensi
# 1. Buku Modul Praktikum Algoritma dan Pemrograman, Politeknik Purbaya (Halaman 23–24).
# 2. Python Documentation — https://docs.python.org/3/
# 3. Tutorial Python Dasar, W3Schools — https://www.w3schools.com/python/
