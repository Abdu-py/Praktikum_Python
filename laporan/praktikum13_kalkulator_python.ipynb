# %% [markdown]
# # Laporan Praktikum
# ## Program Kalkulator Sederhana Menggunakan Python
#
# **Nama:** M. ABDU MUKHLISIN MAWARDI
# **NIM:** 2402038
# **Kelas/Prodi:** TI 3A/TEKNIK INFORMATIKA
# **Mata Kuliah:** Pemrograman Python

# %% [markdown]
# ## 1. Pendahuluan
# Python merupakan salah satu bahasa pemrograman yang mudah dipahami dan banyak digunakan, terutama bagi pemula.
# Pada praktikum ini dibuat sebuah program kalkulator sederhana berbasis teks yang dapat melakukan operasi aritmatika dasar
# seperti penjumlahan, pengurangan, perkalian, dan pembagian.

# %% [markdown]
# ## 2. Tujuan Praktikum
# - Memahami konsep input dan output pada Python
# - Memahami penggunaan fungsi (function)
# - Mengimplementasikan logika percabangan (if-else)
# - Membuat program kalkulator sederhana menggunakan Python

# %% [markdown]
# ## 3. Program
# Berikut adalah source code program kalkulator sederhana menggunakan bahasa pemrograman Python:

# %%
print("Calculator Python")
print("----------------")

print("1. Penjumlahan")
print("2. Pengurangan")
print("3. Perkalian")
print("4. Pembagian")
print("----------------")

def penjumlahan(x, y):
    return x + y

def pengurangan(x, y):
    return x - y

def perkalian(x, y):
    return x * y

def pembagian(x, y):
    return x / y

tipe = input("Silakan masukan nomor yang kalian pilih : ")

if tipe in ('1', '2', '3', '4'):
    angka1 = float(input("Angka pertama : "))
    angka2 = float(input("Angka kedua : "))
    print("----------------")
    if tipe == '1':
        print("Jawabannya adalah :", penjumlahan(angka1, angka2))
    elif tipe == '2':
        print("Jawabannya adalah :", pengurangan(angka1, angka2))
    elif tipe == '3':
        print("Jawabannya adalah :", perkalian(angka1, angka2))
    elif tipe == '4':
        print("Jawabannya adalah :", pembagian(angka1, angka2))
    print("----------------")
else:
    print("Pilihan tidak valid")

# %% [markdown]
# ## 4. Analisis Program
# Program ini bekerja dengan cara menampilkan menu operasi matematika kepada pengguna.
# Pengguna diminta memilih jenis operasi yang diinginkan, kemudian memasukkan dua buah angka.
# Setiap operasi aritmatika diimplementasikan dalam bentuk fungsi agar program lebih terstruktur dan mudah dipahami.
# Percabangan `if-elif` digunakan untuk menentukan operasi yang dipilih oleh pengguna.

# %% [markdown]
# ## 5. Kesimpulan
# Dari praktikum ini dapat disimpulkan bahwa bahasa pemrograman Python sangat cocok digunakan
# untuk membuat program sederhana seperti kalkulator. Program ini membantu memahami konsep dasar
# pemrograman seperti fungsi, input-output, dan percabangan.

# %% [markdown]
# ## 6. Referensi
# - Modul Pemrograman Python
# - Dokumentasi Resmi Python (https://docs.python.org/3/)
